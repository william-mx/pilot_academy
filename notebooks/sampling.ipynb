# %%
from pathlib import Path
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from functools import partial

from pilot_academy.data.io import read_fn
from pilot_academy.data.sampling import balanced_sampling_with_augmentation_tags

# %%
# Paths
PROJECT_DIR = Path("/workspaces/pilot_academy")
DATA_DIR = PROJECT_DIR / "data" 
OUT_DIR = PROJECT_DIR / "outputs" 
CONFIG_DIR = PROJECT_DIR / "config"

DATASET_NAME = "all_towns_with_weather"
DS_DIR = DATA_DIR / f"{DATASET_NAME}" / "raw"
IMAGES_DIR = DS_DIR / "images"

df_path = DS_DIR / "df_annotations.csv"
label_to_id_path = DS_DIR / "label_to_id.json"
action_to_id_path = DS_DIR / "action_to_id.json"

# %%
# Load annotations
df_annotations = pd.read_csv(df_path, index_col="frame_index")

# Load mappings
with open(action_to_id_path) as f:
    action_to_id = json.load(f)

with open(label_to_id_path) as f:
    label_to_id = {
        tuple(k.split("|")): int(v)
        for k, v in json.load(f).items()
    }


# Collect images
image_paths = sorted(IMAGES_DIR.glob("*.png"))

# map filename -> full path
paths_by_name = {p.name: p for p in image_paths}

needed = set(df_annotations["image_name"])
available = set(paths_by_name.keys())

missing = needed - available
if missing:
    raise FileNotFoundError(
        f"{len(missing)} missing image(s). First: {next(iter(missing))}"
    )


# Configuration
crop_ymin = 100
grayscale = True

configured_read_fn = partial(
    read_fn,
    crop_ymin=crop_ymin,
    grayscale=grayscale,
)

# %%
# Use df_annotations instead of df
df = df_annotations

CLASS_COL = "class_id"   # change if your column name differs

print("Original class distribution:")
print(df[CLASS_COL].value_counts().sort_index())
print()

# Test 1: Manual n_samples_per_class
print("\n" + "="*60)
print("TEST 1: Manual n_samples_per_class=500")
print("="*60)
balanced_df1 = balanced_sampling_with_augmentation_tags(
    df=df,
    class_column=CLASS_COL,
    n_samples_per_class=500,
    seed=42
)

# Test 2: balancing_mode='min' (no augmentation needed)
print("\n" + "="*60)
print("TEST 2: balancing_mode='min' (subsample all to smallest class)")
print("="*60)
balanced_df2 = balanced_sampling_with_augmentation_tags(
    df=df,
    class_column=CLASS_COL,
    balancing_mode='min',
    seed=42
)

# Test 3: balancing_mode='max' (augment all to largest class)
print("\n" + "="*60)
print("TEST 3: balancing_mode='max' (augment all to largest class)")
print("="*60)
balanced_df3 = balanced_sampling_with_augmentation_tags(
    df=df,
    class_column=CLASS_COL,
    balancing_mode='max',
    seed=42
)

# Test 4: balancing_mode='mean'
print("\n" + "="*60)
print("TEST 4: balancing_mode='mean'")
print("="*60)
balanced_df4 = balanced_sampling_with_augmentation_tags(
    df=df,
    class_column=CLASS_COL,
    balancing_mode='mean',
    seed=42
)

# Test 5: balancing_mode='median'
print("\n" + "="*60)
print("TEST 5: balancing_mode='median'")
print("="*60)
balanced_df5 = balanced_sampling_with_augmentation_tags(
    df=df,
    class_column=CLASS_COL,
    balancing_mode='median',
    seed=42
)

# Test 6: Combining with class selection
# IMPORTANT: exclude_classes must match the dtype/values in df[CLASS_COL]
print("\n" + "="*60)
print("TEST 6: balancing_mode='mean' with class exclusion")
print("="*60)

# Example A (exclude by numeric id):
# balanced_df6 = balanced_sampling_with_augmentation_tags(
#     df=df,
#     class_column=CLASS_COL,
#     exclude_classes=[3],   # replace 3 with the id you want excluded
#     balancing_mode='mean',
#     seed=42
# )

# Example B (exclude by string label) — only if class_id is actually strings
balanced_df6 = balanced_sampling_with_augmentation_tags(
    df=df,
    class_column=CLASS_COL,
    exclude_classes=['u_turn'],
    balancing_mode='mean',
    seed=42
)
# Out:
# Original class distribution:
# class_id
# 1     1135
# 2     1185
# 3     1005
# 4     1180
# 5      570
# 6     1082
# 7     1622
# 8     1176
# 9    44144
# Name: count, dtype: int64
#
#
# ============================================================
# TEST 1: Manual n_samples_per_class=500
# ============================================================
#
# ============================================================
# Balanced Sampling Summary
# ============================================================
# Target samples per class: 500
# Number of classes: 9
# Total samples: 4500
#
# Per-class breakdown:
# ------------------------------------------------------------
# Class 9:
#   Original:  44144 | Subsampled to 500
#   Final:    500 | Augmented:      0
# Class 2:
#   Original:   1185 | Subsampled to 500
#   Final:    500 | Augmented:      0
# Class 7:
#   Original:   1622 | Subsampled to 500
#   Final:    500 | Augmented:      0
# Class 8:
#   Original:   1176 | Subsampled to 500
#   Final:    500 | Augmented:      0
# Class 4:
#   Original:   1180 | Subsampled to 500
#   Final:    500 | Augmented:      0
# Class 3:
#   Original:   1005 | Subsampled to 500
#   Final:    500 | Augmented:      0
# Class 6:
#   Original:   1082 | Subsampled to 500
#   Final:    500 | Augmented:      0
# Class 5:
#   Original:    570 | Subsampled to 500
#   Final:    500 | Augmented:      0
# Class 1:
#   Original:   1135 | Subsampled to 500
#   Final:    500 | Augmented:      0
# ------------------------------------------------------------
# Overall augmentation: 0 / 4500 samples (0.0%)
# ============================================================
#
#
# ============================================================
# TEST 2: balancing_mode='min' (subsample all to smallest class)
# ============================================================
# Balancing mode 'min' selected:
#   Class counts: min=570, max=44144, mean=5899.9, median=1176.0
#   Using n_samples_per_class = 570
#
#
# ============================================================
# Balanced Sampling Summary
# ============================================================
# Target samples per class: 570
# Number of classes: 9
# Total samples: 5130
#
# Per-class breakdown:
# ------------------------------------------------------------
# Class 9:
#   Original:  44144 | Subsampled to 570
#   Final:    570 | Augmented:      0
# Class 2:
#   Original:   1185 | Subsampled to 570
#   Final:    570 | Augmented:      0
# Class 7:
#   Original:   1622 | Subsampled to 570
#   Final:    570 | Augmented:      0
# Class 8:
#   Original:   1176 | Subsampled to 570
#   Final:    570 | Augmented:      0
# Class 4:
#   Original:   1180 | Subsampled to 570
#   Final:    570 | Augmented:      0
# Class 3:
#   Original:   1005 | Subsampled to 570
#   Final:    570 | Augmented:      0
# Class 6:
#   Original:   1082 | Subsampled to 570
#   Final:    570 | Augmented:      0
# Class 5:
#   Original:    570 | Subsampled to 570
#   Final:    570 | Augmented:      0
# Class 1:
#   Original:   1135 | Subsampled to 570
#   Final:    570 | Augmented:      0
# ------------------------------------------------------------
# Overall augmentation: 0 / 5130 samples (0.0%)
# ============================================================
#
#
# ============================================================
# TEST 3: balancing_mode='max' (augment all to largest class)
# ============================================================
# Balancing mode 'max' selected:
#   Class counts: min=570, max=44144, mean=5899.9, median=1176.0
#   Using n_samples_per_class = 44144
#
#
# ============================================================
# Balanced Sampling Summary
# ============================================================
# Target samples per class: 44144
# Number of classes: 9
# Total samples: 397296
#
# Per-class breakdown:
# ------------------------------------------------------------
# Class 9:
#   Original:  44144 | Subsampled to 44144
#   Final:  44144 | Augmented:      0
# Class 2:
#   Original:   1185 | Repeated 37x + 299 samples
#   Final:  44144 | Augmented:  42959
# Class 7:
#   Original:   1622 | Repeated 27x + 350 samples
#   Final:  44144 | Augmented:  42522
# Class 8:
#   Original:   1176 | Repeated 37x + 632 samples
#   Final:  44144 | Augmented:  42968
# Class 4:
#   Original:   1180 | Repeated 37x + 484 samples
#   Final:  44144 | Augmented:  42964
# Class 3:
#   Original:   1005 | Repeated 43x + 929 samples
#   Final:  44144 | Augmented:  43139
# Class 6:
#   Original:   1082 | Repeated 40x + 864 samples
#   Final:  44144 | Augmented:  43062
# Class 5:
#   Original:    570 | Repeated 77x + 254 samples
#   Final:  44144 | Augmented:  43574
# Class 1:
#   Original:   1135 | Repeated 38x + 1014 samples
#   Final:  44144 | Augmented:  43009
# ------------------------------------------------------------
# Overall augmentation: 344197 / 397296 samples (86.6%)
# ============================================================
#
#
# ============================================================
# TEST 4: balancing_mode='mean'
# ============================================================
# Balancing mode 'mean' selected:
#   Class counts: min=570, max=44144, mean=5899.9, median=1176.0
#   Using n_samples_per_class = 5899
#
#
# ============================================================
# Balanced Sampling Summary
# ============================================================
# Target samples per class: 5899
# Number of classes: 9
# Total samples: 53091
#
# Per-class breakdown:
# ------------------------------------------------------------
# Class 9:
#   Original:  44144 | Subsampled to 5899
#   Final:   5899 | Augmented:      0
# Class 2:
#   Original:   1185 | Repeated 4x + 1159 samples
#   Final:   5899 | Augmented:   4714
# Class 7:
#   Original:   1622 | Repeated 3x + 1033 samples
#   Final:   5899 | Augmented:   4277
# Class 8:
#   Original:   1176 | Repeated 5x + 19 samples
#   Final:   5899 | Augmented:   4723
# Class 4:
#   Original:   1180 | Repeated 4x + 1179 samples
#   Final:   5899 | Augmented:   4719
# Class 3:
#   Original:   1005 | Repeated 5x + 874 samples
#   Final:   5899 | Augmented:   4894
# Class 6:
#   Original:   1082 | Repeated 5x + 489 samples
#   Final:   5899 | Augmented:   4817
# Class 5:
#   Original:    570 | Repeated 10x + 199 samples
#   Final:   5899 | Augmented:   5329
# Class 1:
#   Original:   1135 | Repeated 5x + 224 samples
#   Final:   5899 | Augmented:   4764
# ------------------------------------------------------------
# Overall augmentation: 38237 / 53091 samples (72.0%)
# ============================================================
#
#
# ============================================================
# TEST 5: balancing_mode='median'
# ============================================================
# Balancing mode 'median' selected:
#   Class counts: min=570, max=44144, mean=5899.9, median=1176.0
#   Using n_samples_per_class = 1176
#
#
# ============================================================
# Balanced Sampling Summary
# ============================================================
# Target samples per class: 1176
# Number of classes: 9
# Total samples: 10584
#
# Per-class breakdown:
# ------------------------------------------------------------
# Class 9:
#   Original:  44144 | Subsampled to 1176
#   Final:   1176 | Augmented:      0
# Class 2:
#   Original:   1185 | Subsampled to 1176
#   Final:   1176 | Augmented:      0
# Class 7:
#   Original:   1622 | Subsampled to 1176
#   Final:   1176 | Augmented:      0
# Class 8:
#   Original:   1176 | Subsampled to 1176
#   Final:   1176 | Augmented:      0
# Class 4:
#   Original:   1180 | Subsampled to 1176
#   Final:   1176 | Augmented:      0
# Class 3:
#   Original:   1005 | Repeated 1x + 171 samples
#   Final:   1176 | Augmented:    171
# Class 6:
#   Original:   1082 | Repeated 1x + 94 samples
#   Final:   1176 | Augmented:     94
# Class 5:
#   Original:    570 | Repeated 2x + 36 samples
#   Final:   1176 | Augmented:    606
# Class 1:
#   Original:   1135 | Repeated 1x + 41 samples
#   Final:   1176 | Augmented:     41
# ------------------------------------------------------------
# Overall augmentation: 912 / 10584 samples (8.6%)
# ============================================================
#
#
# ============================================================
# TEST 6: balancing_mode='mean' with class exclusion
# ============================================================
# Balancing mode 'mean' selected:
#   Class counts: min=570, max=44144, mean=5899.9, median=1176.0
#   Using n_samples_per_class = 5899
#
#
# ============================================================
# Balanced Sampling Summary
# ============================================================
# Target samples per class: 5899
# Number of classes: 9
# Total samples: 53091
#
# Per-class breakdown:
# ------------------------------------------------------------
# Class 9:
#   Original:  44144 | Subsampled to 5899
#   Final:   5899 | Augmented:      0
# Class 2:
#   Original:   1185 | Repeated 4x + 1159 samples
#   Final:   5899 | Augmented:   4714
# Class 7:
#   Original:   1622 | Repeated 3x + 1033 samples
#   Final:   5899 | Augmented:   4277
# Class 8:
#   Original:   1176 | Repeated 5x + 19 samples
#   Final:   5899 | Augmented:   4723
# Class 4:
#   Original:   1180 | Repeated 4x + 1179 samples
#   Final:   5899 | Augmented:   4719
# Class 3:
#   Original:   1005 | Repeated 5x + 874 samples
#   Final:   5899 | Augmented:   4894
# Class 6:
#   Original:   1082 | Repeated 5x + 489 samples
#   Final:   5899 | Augmented:   4817
# Class 5:
#   Original:    570 | Repeated 10x + 199 samples
#   Final:   5899 | Augmented:   5329
# Class 1:
#   Original:   1135 | Repeated 5x + 224 samples
#   Final:   5899 | Augmented:   4764
# ------------------------------------------------------------
# Overall augmentation: 38237 / 53091 samples (72.0%)
# ============================================================
